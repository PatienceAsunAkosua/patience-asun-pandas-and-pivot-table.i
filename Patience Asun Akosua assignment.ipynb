# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('autos.csv')

# %%
df
# Out:
#      symboling         make fuel_type aspiration  num_of_doors   body_style  \
# 0            3  alfa-romero       gas        std             2  convertible
# 1            3  alfa-romero       gas        std             2  convertible
# 2            1  alfa-romero       gas        std             2    hatchback
# 3            2         audi       gas        std             4        sedan
# 4            2         audi       gas        std             4        sedan
# ..         ...          ...       ...        ...           ...          ...
# 188         -1        volvo       gas        std             4        sedan
# 189         -1        volvo       gas      turbo             4        sedan
# 190         -1        volvo       gas        std             4        sedan
# 191         -1        volvo    diesel      turbo             4        sedan
# 192         -1        volvo       gas      turbo             4        sedan
#
# ...

# %%
df.head(8)
# Out:
#    symboling         make fuel_type aspiration  num_of_doors   body_style  \
# 0          3  alfa-romero       gas        std             2  convertible
# 1          3  alfa-romero       gas        std             2  convertible
# 2          1  alfa-romero       gas        std             2    hatchback
# 3          2         audi       gas        std             4        sedan
# 4          2         audi       gas        std             4        sedan
# 5          2         audi       gas        std             2        sedan
# 6          1         audi       gas        std             4        sedan
# 7          1         audi       gas        std             4        wagon
#
#   drive_wheels engine_location  wheel_base  length  ...  engine_size  \
# 0          rwd           front        88.6   168.8  ...          130
# 1          rwd           front        88.6   168.8  ...          130
# 2          rwd           front        94.5   171.2  ...          152
# ...

# %%
grpy=df.groupby('make')

# %%
minimum_price=grpy['price'].min()

# %%
print(minimum_price)
# Out:
# make
# alfa-romero      13495
# audi             13950
# bmw              16430
# chevrolet         5151
# dodge             5572
# honda             5399
# isuzu             6785
# jaguar           32250
# mazda             5195
# mercedes-benz    25552
# mercury          16503
# mitsubishi        5389
# nissan            5499
# peugot           11900
# plymouth          5572
# porsche          22018
# saab             11850
# subaru            5118
# toyota            5348
# volkswagen        7775
# volvo            12940
# Name: price, dtype: int64

# %%
df.tail(2)
# Out:
#      symboling   make fuel_type aspiration  num_of_doors body_style  \
# 191         -1  volvo    diesel      turbo             4      sedan
# 192         -1  volvo       gas      turbo             4      sedan
#
#     drive_wheels engine_location  wheel_base  length  ...  engine_size  \
# 191          rwd           front       109.1   188.8  ...          145
# 192          rwd           front       109.1   188.8  ...          141
#
#      fuel_system  bore stroke  compression_ratio  horsepower peak_rpm  \
# 191          idi  3.01   3.40                 23         106     4800
# 192         mpfi  3.78   3.15                  9         114     5400
#
#      city_mpg  highway_mpg  price
# 191        26           27  22470
# 192        19           25  22625
#
# [2 rows x 25 columns]

# %%
column_name=['make','fuel_type']
print(df[column_name].tail(2))
# Out:
#       make fuel_type
# 191  volvo    diesel
# 192  volvo       gas

# %%
p
# Out:
#           symboling        make              aspiration        num_of_doors  \
# fuel_type    diesel  gas diesel          gas     diesel    gas       diesel
# 0               NaN  3.0    NaN  alfa-romero        NaN    std          NaN
# 1               NaN  3.0    NaN  alfa-romero        NaN    std          NaN
# 2               NaN  1.0    NaN  alfa-romero        NaN    std          NaN
# 3               NaN  2.0    NaN         audi        NaN    std          NaN
# 4               NaN  2.0    NaN         audi        NaN    std          NaN
# ..              ...  ...    ...          ...        ...    ...          ...
# 188             NaN -1.0    NaN        volvo        NaN    std          NaN
# 189             NaN -1.0    NaN        volvo        NaN  turbo          NaN
# 190             NaN -1.0    NaN        volvo        NaN    std          NaN
# 191            -1.0  NaN  volvo          NaN      turbo    NaN          4.0
# ...

# %%
std_dev=np.std(df).min()
std_dev
# Out:
# 0.2716780076438119

# %%
dict1={'make':['Alfa-Romeo','mercedes-benz','audi'],'number_of_doors':[2,4,6]}
dict2={'make':['porsche','volvo','nissan'],'number_of_doors':[40,45,50]}
df1=pd.DataFrame(dict1)
df2=pd.DataFrame(dict2)
merged_df =pd.concat([df1,df2],ignore_index=True)
print(merged_df)
# Out:
#             make  number_of_doors
# 0     Alfa-Romeo                2
# 1  mercedes-benz                4
# 2           audi                6
# 3        porsche               40
# 4          volvo               45
# 5         nissan               50
